# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
data_df = application_df.drop(columns=['EIN'])
data_df.head(5)
# Out:
#                                        NAME APPLICATION_TYPE  \
# 0              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Determine the number of unique values in each column.
unique_df = data_df.nunique()
unique_df
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
type_df = data_df['APPLICATION_TYPE'].value_counts()
type_df
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at NAME value counts for binning
name_counts = application_df['NAME'].value_counts()
#  How many name counts are greater than 5?
name_counts[name_counts>5]
# Out:
# PARENT BOOSTER USA INC                             1260
# TOPS CLUB INC                                       765
# UNITED STATES BOWLING CONGRESS INC                  700
# WASHINGTON STATE UNIVERSITY                         492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC     408
#                                                    ...
# OLD OAK CLIFF CONSERVATION LEAGUE INC                 6
# AMERICAN NEPHROLOGY NURSES ASSOCIATION                6
# HUMBLE ISD EDUCATIONAL SUPPORT GROUPS INC             6
# PROFESSIONAL LOADMASTER ASSOCIATION                   6
# CBMC INC                                              6
# Name: NAME, Length: 354, dtype: int64

# %%
# Determine which values to replace if counts are less than or equal to 5.
names_to_replace = list(name_counts[name_counts <= 5].index)

# Replace in dataframe
for app in names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(app,"Other")
    
# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# Other                                           20043
# PARENT BOOSTER USA INC                           1260
# TOPS CLUB INC                                     765
# UNITED STATES BOWLING CONGRESS INC                700
# WASHINGTON STATE UNIVERSITY                       492
#                                                 ...
# HABITAT FOR HUMANITY INTERNATIONAL                  6
# DAMAGE PREVENTION COUNCIL OF TEXAS                  6
# FLEET RESERVE ASSOCIATION                           6
# HUGH OBRIAN YOUTH LEADERSHIP                        6
# INTERNATIONAL CONGRESS OF CHURCHES MINISTERS        6
# Name: NAME, Length: 355, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

#choosing cutoff value as 500
application_types_to_replace = list(type_df[type_df < 500].index)
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_count = data_df['CLASSIFICATION'].value_counts()
classification_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_count[classification_count > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

#choosing cutoff value as 1000
classifications_to_replace= list(classification_count[classification_count < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_with_dummies_df = pd.get_dummies(application_df)

# Generate our categorical variable lists
application_cat = application_df.dtypes[application_df.dtypes == "object"].index.tolist()

# %%
# Split our preprocessed data into our features and target arrays
X = application_with_dummies_df.drop(["IS_SUCCESSFUL"], axis='columns').values
y = application_with_dummies_df["IS_SUCCESSFUL"].values

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

num_input_features = len(X_train[0])
layer_1_nodes = 80
layer_2_nodes = 30
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=layer_1_nodes, 
                          input_dim=num_input_features, 
                          activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer_2_nodes, 
                          input_dim=layer_1_nodes, 
                          activation='relu'))

# Output layer
nn.add(
    tf.keras.layers.Dense(units=1, 
                          input_dim=layer_2_nodes, 
                          activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                32000
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 34,461
# Trainable params: 34,461
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 10s 5ms/step - loss: 0.4711 - accuracy: 0.7772
# Epoch 2/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4317 - accuracy: 0.7941
# Epoch 3/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.4273 - accuracy: 0.7944
# Epoch 4/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4259 - accuracy: 0.7963
# Epoch 5/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4238 - accuracy: 0.7961
# Epoch 6/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4214 - accuracy: 0.7974
# Epoch 7/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4207 - accuracy: 0.7990
# Epoch 8/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4200 - accuracy: 0.7984
# Epoch 9/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4187 - accuracy: 0.7994
# Epoch 10/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4177 - accuracy: 0.7998
# Epoch 11/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4170 - accuracy: 0.8015
# Epoch 12/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4160 - accuracy: 0.8009
# Epoch 13/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4151 - accuracy: 0.8016
# Epoch 14/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4149 - accuracy: 0.8019
# Epoch 15/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4143 - accuracy: 0.8028
# Epoch 16/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4134 - accuracy: 0.8033
# Epoch 17/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4124 - accuracy: 0.8038
# Epoch 18/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4119 - accuracy: 0.8039
# Epoch 19/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4119 - accuracy: 0.8047
# Epoch 20/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4106 - accuracy: 0.8044
# Epoch 21/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4100 - accuracy: 0.8047
# Epoch 22/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4094 - accuracy: 0.8060
# Epoch 23/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4090 - accuracy: 0.8055
# Epoch 24/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4085 - accuracy: 0.8054
# Epoch 25/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4077 - accuracy: 0.8054
# Epoch 26/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4070 - accuracy: 0.8070
# Epoch 27/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4062 - accuracy: 0.8073
# Epoch 28/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4059 - accuracy: 0.8086
# Epoch 29/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4049 - accuracy: 0.8088
# Epoch 30/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4047 - accuracy: 0.8094
# Epoch 31/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4040 - accuracy: 0.8089
# Epoch 32/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4041 - accuracy: 0.8089
# Epoch 33/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4029 - accuracy: 0.8094
# Epoch 34/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4029 - accuracy: 0.8085
# Epoch 35/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4021 - accuracy: 0.8100
# Epoch 36/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.4020 - accuracy: 0.8105
# Epoch 37/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4016 - accuracy: 0.8102
# Epoch 38/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4015 - accuracy: 0.8098
# Epoch 39/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3999 - accuracy: 0.8099
# Epoch 40/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3996 - accuracy: 0.8109
# Epoch 41/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4001 - accuracy: 0.8108
# Epoch 42/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4000 - accuracy: 0.8110
# Epoch 43/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3989 - accuracy: 0.8118
# Epoch 44/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3985 - accuracy: 0.8113
# Epoch 45/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3974 - accuracy: 0.8120
# Epoch 46/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3972 - accuracy: 0.8122
# Epoch 47/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3970 - accuracy: 0.8118
# Epoch 48/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3969 - accuracy: 0.8125
# Epoch 49/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3967 - accuracy: 0.8122
# Epoch 50/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3965 - accuracy: 0.8119
# Epoch 51/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3958 - accuracy: 0.8118
# Epoch 52/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3956 - accuracy: 0.8127
# Epoch 53/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3957 - accuracy: 0.8127
# Epoch 54/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3946 - accuracy: 0.8123
# Epoch 55/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3940 - accuracy: 0.8136
# Epoch 56/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3936 - accuracy: 0.8146
# Epoch 57/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3944 - accuracy: 0.8123
# Epoch 58/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3936 - accuracy: 0.8142
# Epoch 59/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3928 - accuracy: 0.8144
# Epoch 60/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3923 - accuracy: 0.8136
# Epoch 61/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3930 - accuracy: 0.8142
# Epoch 62/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3918 - accuracy: 0.8150
# Epoch 63/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3916 - accuracy: 0.8143
# Epoch 64/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.3916 - accuracy: 0.8141
# Epoch 65/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3913 - accuracy: 0.8143
# Epoch 66/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3912 - accuracy: 0.8146
# Epoch 67/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3908 - accuracy: 0.8153
# Epoch 68/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3909 - accuracy: 0.8141
# Epoch 69/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3903 - accuracy: 0.8153
# Epoch 70/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3901 - accuracy: 0.8151
# Epoch 71/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3905 - accuracy: 0.8157
# Epoch 72/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3905 - accuracy: 0.8149
# Epoch 73/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3892 - accuracy: 0.8156
# Epoch 74/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3888 - accuracy: 0.8155
# Epoch 75/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3890 - accuracy: 0.8148
# Epoch 76/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3886 - accuracy: 0.8150
# Epoch 77/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.3883 - accuracy: 0.8156
# Epoch 78/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3873 - accuracy: 0.8165
# Epoch 79/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3881 - accuracy: 0.8158
# Epoch 80/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3877 - accuracy: 0.8155
# Epoch 81/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3878 - accuracy: 0.8160
# Epoch 82/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3871 - accuracy: 0.8162
# Epoch 83/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3872 - accuracy: 0.8169
# Epoch 84/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3873 - accuracy: 0.8172
# Epoch 85/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3866 - accuracy: 0.8173
# Epoch 86/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3871 - accuracy: 0.8181
# Epoch 87/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3864 - accuracy: 0.8162
# Epoch 88/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3867 - accuracy: 0.8161
# Epoch 89/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3858 - accuracy: 0.8174
# Epoch 90/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3857 - accuracy: 0.8176
# Epoch 91/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3852 - accuracy: 0.8177
# Epoch 92/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3852 - accuracy: 0.8172
# Epoch 93/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.3846 - accuracy: 0.8182
# Epoch 94/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.3854 - accuracy: 0.8169
# Epoch 95/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3847 - accuracy: 0.8183
# Epoch 96/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.3844 - accuracy: 0.8168
# Epoch 97/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3851 - accuracy: 0.8180
# Epoch 98/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3839 - accuracy: 0.8178
# Epoch 99/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3842 - accuracy: 0.8174
# Epoch 100/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.3840 - accuracy: 0.8173

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.4770 - accuracy: 0.7890 - 617ms/epoch - 2ms/step
# Loss: 0.4769724905490875, Accuracy: 0.7890378832817078

# %%
# Export our model to HDF5 file
nn.save('opt_alphabet_soup.h5')

# %%
# Export our model to HDF5 file
from google.colab import drive
drive.mount('/content/drive')
# Specify the path in your Google Drive where you want to save the file
file_path ='/content/drive/MyDrive/DeepLearning-21/Deeplearning-21/Starter_Code(7)/Starter_Code/Step1_Step2/opt_alphabet_soup.h5'
nn.save(file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
